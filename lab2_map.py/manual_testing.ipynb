# %% [markdown]
# # This is my manual testing for the lab where i will be testing all of the classes

# %% [markdown]
# ### This Manual testing bellow is for the Parent class (shape)

# %%
from shape import Shape 

s = Shape(3,4)  
s # succsesfull

s.translate(1,2)

s # succsesfull
# Out:
# shape(x = 4.0, y = 6.0)

# %% [markdown]
# ### This Manual testing is for circel (child class)

# %% [markdown]
# ### This Manual testing is for rectangle (child class)
