# %% [markdown]
# # Manual testing for all classes will be in this file.
#
# ### I have also structured this file so that you can easily see what class i am testing, and exactley whay in the class that is getting tested.

# %% [markdown]
# ## >>>This Manual testing bellow is for the Parent class (shape) <<<

# %% [markdown]
# ### Testing to import shape class

# %%
from shape import Shape 
# Testing to see if i can import the class.

# Now testing if i can create a object from this class 
s = Shape(3,4)  
s # succsesfull
# Out:
# shape(x = 3.0, y = 4.0)

# %% [markdown]
# ### Testing to translate

# %%
# Testing to see if i can translate the placement in the coordinate. 
s.translate(1,2)
s # succsesfull
# Out:
# shape(x = 4.0, y = 6.0)

# %% [markdown]
# ### Testing to see if i can compare two shapes

# %%
 

s2 = Shape(0, 0)
print(s == s2) # gives the right Error

# %% [markdown]
# ## >>>This Manual testing is for rectangle (child class)<<<

# %% [markdown]
# ### Testing to import rectangle class

# %%
from rectangle import Rectangle #succsesfull

# %% [markdown]
# ### Testing to create a rectangle obejct

# %%
r = Rectangle(0, 0, 4, 6)

print("area", r.area)

print("perimeter", r.perimeter)
# sucsessfull
# Out:
# area 24.0
# perimeter 20.0

# %% [markdown]
# ### Testing to see if funcionallity works

# %%
r = Rectangle(0, 0, 4, 6)
print("width:", r.width)
print("height:", r.height)
print("area:", r.area)
print("perimeter:", r.perimeter)
#succsessfull
# Out:
# width: 4.0
# height: 6.0
# area: 24.0
# perimeter: 20.0

# %% [markdown]
# ### Testing to see if repr works

# %%
r = Rectangle(2, 5, 6, 3)
r #sucessfull
# Out:
# rectangle(x = 2.0, y = 5.0, width = 6.0, height = 3.0)

# %% [markdown]
# ### Testing string for more readable text

# %%
r = Rectangle(2, 5, 4, 6)

print(r)
# Out:
# rectangle placement is on : (2.0, 5.0 the width 4.0, the height 6.0)

# %% [markdown]
# ## >>>This Manual testing is for circle (child class)<<<

# %%
from circle import Circle
#Succsessfull

# %% [markdown]
# ### Testing to create object

# %%
c = Circle(3, 4, 5)
print(c) #succsessfull
# Out:
#  shape placement is : (3.0, 4.0)

# %% [markdown]
# ### Testing to see area, circumfrunce and radius

# %%
print("radius:", c.radius)
print("area:", c.area)
print("perimeter:", c.perimeter)
# Out:
# radius: 5.0
# area: 78.53981633974483
# perimeter: 31.41592653589793

# %% [markdown]
# ### Testing the repr

# %%
c = Circle(2, 5, 4)

repr(c) #succsessfull
# Out:
# 'circle(x = 2.0, y = 5.0 radius = 4.0)'

# %% [markdown]
# #### Testing str

# %%
print(c) #succsessfull
# Out:
# circle placement is : (2.0, 5.0) with radius 4.0

# %% [markdown]
# # >>> Comparing both Rectangle and Circle each other <<<

# %%
from circle import Circle
from rectangle import Rectangle 

# Note that this test is from the instruktions on the lab, i found it helpfull and will use it

circle1 = Circle(x = 0, y = 0, radius = 1)

circle2 = Circle(x = 1, y = 1, radius = 1)

rectangle = Rectangle(x = 0, y = 0, width = 1, height = 1)

print(circle1 == circle2) #succsesfull 

print(circle2 == rectangle) #succsessfull 

circle1.translate(5, 3)

circle1.translate(3, 5) #succsessfull TypeError when input "THREE"

circle3 = Circle(radius = 3)

circle3 > circle1

rectangle2 = Rectangle(width = 3, height = "5") #succsesfull
# Out:
# True
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 24
#      20 circle3 = Circle(radius = 3)
#      22 circle3 > circle1
# ---> 24 rectangle2 = Rectangle(width = 3, height = "5")
#
# File ~/Documents/Github/Python_Zakaria_Nasra_DE25/lab2_map.py/rectangle.py:15, in Rectangle.__init__(self, x, y, width, height)
#      13     raise TypeError("width has to be a number")
#      14 if not isinstance(height,(int, float)):
# ---> 15     raise TypeError("height has to be a number")
#      18 # i kept the values private, this is so i can have control of how they are set
#      19 self._width = float(width)
#
# TypeError: height has to be a number
