# %% [markdown]
# # This is my manual testing for the lab where i will be testing all my shape

# %%
from shape import shape 

shape1 = shape(3,4)

print(f"position of shape1 is {shape1.x}, {shape1.y}")

shape2 = shape.translate(5,6)
# Out:
# position of shape1 is 3.0, 4.0
