# %% [markdown]
# # Manual Testing of Vector Class

# %%
from vector import Vector

#vector with coordinate 2 and 5 
v1 = Vector(2, 5)
print (v1)
# Out:
# Vector(2.0, 5.0)

# %%
print(f"{len(v1)}")  #Output: 2

print(f"{v1.numbers =}")

print(f"{v1 + v2 = }")
# Out:
# 2
# v1.numbers =(2.0, 5.0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 print(f"{len(v1)}")  #Output: 2
#       3 print(f"{v1.numbers =}")
# ----> 5 print(f"{v1 + v2 = }")
#
# NameError: name 'v2' is not defined

# %% [markdown]
# Testing correct error

# %%
v1 = Vector(1, 2,)
v2 = Vector(1,2,3)



try:
    v1 + v2
except TypeError as e:
    print(e)
# Out:
# Both must be Vector and have the same length

# %%
repr("1")
# Out:
# "'1'"
